# %%
import os
from knowledge_propagation.utils import vars, io, extractor, misc
rel_extract_prompt = """
You are given an input document and a set of question–answer pairs. Your task is to extract relationships being discussed.  

A relationship describes how two entity types are connected. For each relationship, output in the following format:  

<relation_triplet>e1 -> relation -> e2</relation_triplet>  
<relation_template>Natural language template of the relation</relation_template>  

**Example:**  
<relation_triplet>[person] -> birth_place -> [country]</relation_triplet>  
<relation_template>The birth place of [person] is [country].</relation_template>  

**Instructions:**  
1. Read the document and QA pairs carefully.
2. Identify entities such as people, places, organizations, events, objects, or concepts.
3. Express relationships at the **entity type** level (e.g., `[person] -> birth_place -> [country]`).
4. For each relationship, produce:
   - A `<relation_triplet>` tag describing the relation in structured form.
   - A `<relation_template>` tag providing a clear, general natural language template.
5. Keep relation templates concise, focusing on the general relation rather than specific instances.
6. Use clear and descriptive relation names (e.g., `author_of`, `capital_of`, `works_at`, `part_of`, `founded_by`).
7. Ensure each relationship is **semantically atomic** (captures a single, direct connection).
8. Avoid duplicates -- list each distinct relationship only once.
9. Extract as many distinct relationships as possible.
10. Do not include any text outside of the specified format.

**Input:**
[Document]
```
{document}
```

[QA pairs]
```
{qa_pairs}  
```
"""

# %%
train_examples = io.load_jsonlines("/home/zliu/zliu/Synthetic_Continued_Pretraining_leo/data/dataset/raw/4K_controlled_RE/train.jsonl")

# %%
# train_examples[0]

# %%
train_example = train_examples[0]

document = train_example['text']
qa_pairs = "\n".join(f"Q: {q['alias_question']}\nA: {q['answer']}" for q in train_example['questions'])

rel_extract_prompt = rel_extract_prompt.format(document=document, qa_pairs=qa_pairs)

print(rel_extract_prompt)
# Out:
# You are given an input document and a set of question–answer pairs. Your task is to extract relationships being discussed.
#
# A relationship describes how two entity types are connected. For each relationship, output in the following format:
#
# <relation_triplet>e1 -> relation -> e2</relation_triplet>
# <relation_template>Natural language template of the relation</relation_template>
#
# **Example:**
# <relation_triplet>[person] -> [birth_place] -> [country]</relation_triplet>
# <relation_template>The birth place of [person] is [country].</relation_template>
#
# **Instructions:**
# 1. Read the document and QA pairs carefully.
# 2. Identify entities such as people, places, organizations, events, objects, or concepts.
# 3. Express relationships at the **entity type** level (e.g., `[person] -> [birth_place] -> [country]`).
# 4. For each relationship, produce:
#    - A `<relation_triplet>` tag describing the relation in structured form.
#    - A `<relation_template>` tag providing a clear, general natural language template.
# 5. Keep relation templates concise, focusing on the general relation rather than specific instances.
# 6. Use clear and descriptive relation names (e.g., `author_of`, `capital_of`, `works_at`, `part_of`, `founded_by`).
# 7. Ensure each relationship is **semantically atomic** (captures a single, direct connection).
# 8. Avoid duplicates -- list each distinct relationship only once.
# 9. Extract as many distinct relationships as possible.
# 10. Do not include any text outside of the specified format.
#
# **Input:**
# [Document]
# ```
# Campbell Software Ltd. began by offering services in German. It then added support for Hebrew to broaden its reach. Eventually, it launched a major initiative in Punjabi, marking a key milestone in its global expansion.
# ```
#
# [QA pairs]
# ```
# Q: What writing system is used by the language that Campbell Software Ltd. launched a major initiative in?
# A: Gurmukhi and Shahmukhi
# Q: What is the ISO 639‑1 code for the language that Campbell Software Ltd. primarily offered services in?
# A: de
# Q: What region is the language that Campbell Software Ltd. primarily offered services in native to?
# A: Central Europe
# ```

# %%
train_example
# Out:
# {'entity_type': 'Language',
#  'entity_names': ['German', 'Hebrew', 'Punjabi'],
#  'subject': 'Campbell Software Ltd.',
#  'gender_type': 'it',
#  'text': 'Campbell Software Ltd. began by offering services in German. It then added support for Hebrew to broaden its reach. Eventually, it launched a major initiative in Punjabi, marking a key milestone in its global expansion.',
#  'questions': [{'question_template': 'What writing system is used by {language}?',
#    'alias_question': 'What writing system is used by the language that Campbell Software Ltd. launched a major initiative in?',
#    'unalias_question': 'What writing system is used by Punjabi?',
#    'alias_question_paraphrase': 'What script is used by the language that Campbell Software Ltd. launched a major initiative in?',
#    'unalias_question_paraphrase': 'What script is used by Punjabi?',
#    'entity_name': 'Punjabi',
#    'answer': 'Gurmukhi and Shahmukhi',
#    'fact_idx': 2},
#   {'question_template': 'What is the ISO 639‑1 code for {language}?',
#    'alias_question': 'What is the ISO 639‑1 code for the language that Campbell Software Ltd. primarily offered services in?',
#    'unalias_question': 'What is the ISO 639‑1 code for German?',
#    'alias_question_paraphrase': 'What is the two-letter ISO code for the language that Campbell Software Ltd. primarily offered services in?',
#    'unalias_question_paraphrase': 'What is the two-letter ISO code for German?',
#    'entity_name': 'German',
#    'answer': 'de',
#    'fact_idx': 0},
#   {'question_template': 'What region is {language} native to?',
#    'alias_question': 'What region is the language that Campbell Software Ltd. primarily offered services in native to?',
#    'unalias_question': 'What region is German native to?',
#    'alias_question_paraphrase': 'In which region is the language that Campbell Software Ltd. primarily offered services in primarily spoken?',
#    'unalias_question_paraphrase': 'In which region is German primarily spoken?',
#    'entity_name': 'German',
#    'answer': 'Central Europe',
#    'fact_idx': 0}],
#  'subject_type': 'company'}

# %%
relation_bank_construction_input = []
for train_example in train_examples:
    document = train_example['text']
    qa_pairs = "\n".join(f"Q: {q['alias_question']}\nA: {q['answer']}" for q in train_example['questions'])
    rel_extract_prompt = rel_extract_prompt.format(document=document, qa_pairs=qa_pairs)
    relation_bank_construction_input.append({
        "entity_type": train_example['entity_type'],
        "text": train_example['text'],
        'subject': train_example['subject'],
        'gender_type': train_example['gender_type'],
        "prompt": rel_extract_prompt,
    })

# %%
len(relation_bank_construction_input)
# Out:
# 4000

# %%
# io.dump_jsonlines(relation_bank_construction_input, "/home/zliu/zliu/Synthetic_Continued_Pretraining_leo/data/dataset/raw/4K_controlled_RE/train_relation_bank_construction.jsonl")

# %%
relation_bank_construction = io.load_jsonlines("/home/zliu/zliu/Synthetic_Continued_Pretraining_leo/data/dataset/raw/4K_controlled_RE/train_relation_bank_construction_generated(gpt-5).jsonl")

# %%
relation_bank = []
for e in relation_bank_construction:
    for r in e["relations"]:
        relation_bank.append(r)

# %%
seen = {}
dedup_key = "relation_triplet"
for d in relation_bank:
    if d[dedup_key] not in seen:
        seen[d[dedup_key]] = d

unique_list = list(seen.values())

# %%
len(unique_list)
# Out:
# 543

# %%
unique_list[0]
# Out:
# {'relation_template': '[company] offers services in [language].',
#  'relation_triplet': '[company] -> [offers_services_in] -> [language]'}

# %%
import regex as re
text = "[company] offers services in [language]"
entity_types = set()
filtered_list = []
for e in unique_list:
    e["entities"] = []
    for t in re.findall(r"\[(.*?)\]", e["relation_template"]):
        normalized_t = t.replace(" ", "_")
        entity_types.add(normalized_t)
        e["relation_template"] = e["relation_template"].replace(f"[{t}]", f"[{normalized_t}]")
        e["entities"].append(normalized_t)
    if len(e["entities"]) != 2:
        continue
    filtered_list.append(e)
    for t in re.findall(r"\[(.*?)\]", e["relation_triplet"]):
        normalized_t = t.replace(" ", "_")
        e["relation_triplet"] = e["relation_triplet"].replace(f"[{t}]", f"[{normalized_t}]")

# entity_types
# len(unique_list)
len(filtered_list)
# Out:
# 463

# %%
seen = {}
dedup_key = "relation_triplet"
for d in filtered_list:
    if d[dedup_key] not in seen:
        seen[d[dedup_key]] = d

unique_list = list(seen.values())

# %%
seen = {}
dedup_key = "relation_triplet"
for d in unique_list:
    if d[relation_template] not in seen:
        seen[d[dedup_key]] = d

unique_list = list(seen.values())

# %%
len(unique_list)
# Out:
# 456

# %%
unique_list
# Out:
# [{'relation_template': '[company] offers services in [language].',
#   'relation_triplet': '[company] -> [offers_services_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] adds support for [language].',
#   'relation_triplet': '[company] -> [adds_support_for] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launches an initiative in [language].',
#   'relation_triplet': '[company] -> [launches_initiative_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[language] uses the [writing_system] writing system.',
#   'relation_triplet': '[language] -> [uses_writing_system] -> [writing_system]',
#   'entities': ['language', 'writing_system']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> [iso_639_1_code] -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': '[language] is native to [region].',
#   'relation_triplet': '[language] -> [native_region] -> [region]',
#   'entities': ['language', 'region']},
#  {'relation_template': 'The [organization] offers services in [language].',
#   'relation_triplet': '[organization] -> offers_services_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [organization] adds support for [language].',
#   'relation_triplet': '[organization] -> adds_support_for -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [organization] launches an initiative in [language].',
#   'relation_triplet': '[organization] -> launches_initiative_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The writing system used by [language] is [script].',
#   'relation_triplet': '[language] -> uses_writing_system -> [script]',
#   'entities': ['language', 'script']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> has_iso_639-1_code -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': '[language] is native to [region].',
#   'relation_triplet': '[language] -> native_to -> [region]',
#   'entities': ['language', 'region']},
#  {'relation_template': '[company] supports the [language] language.',
#   'relation_triplet': '[company] -> [supports_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The [language] language uses the [script] writing system.',
#   'relation_triplet': '[language] -> [uses_writing_system] -> [script]',
#   'entities': ['language', 'script']},
#  {'relation_template': 'The [language] language is native to [region].',
#   'relation_triplet': '[language] -> [native_to_region] -> [region]',
#   'entities': ['language', 'region']},
#  {'relation_template': 'An [organization] launched an [initiative].',
#   'relation_triplet': '[organization] -> launched -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': 'An [initiative] is conducted in [language].',
#   'relation_triplet': '[initiative] -> in_language -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': '[language] uses the [writing_system] writing system.',
#   'relation_triplet': '[language] -> uses_writing_system -> [writing_system]',
#   'entities': ['language', 'writing_system']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [iso_639-1_code].',
#   'relation_triplet': '[language] -> has_iso_639_1_code -> [iso_639-1_code]',
#   'entities': ['language', 'iso_639-1_code']},
#  {'relation_template': '[organization] added support for [language].',
#   'relation_triplet': '[organization] -> added_support_for -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] launched an initiative in [language].',
#   'relation_triplet': '[organization] -> launched_initiative_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> has_iso_639_1_code -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': '[language] is native to [region].',
#   'relation_triplet': '[language] -> native_to_region -> [region]',
#   'entities': ['language', 'region']},
#  {'relation_template': '[company] offers services in [language].',
#   'relation_triplet': '[company] -> offers_services_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] supports [language].',
#   'relation_triplet': '[company] -> supports_language -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launched a major initiative in [language].',
#   'relation_triplet': '[company] -> launched_initiative_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> iso_639_1_code -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': 'An [organization] offers services in [language].',
#   'relation_triplet': '[organization] -> [offers_services_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'An [organization] adds support for [language].',
#   'relation_triplet': '[organization] -> [adds_support_for] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'An [organization] launches an initiative in [language].',
#   'relation_triplet': '[organization] -> [launches_initiative_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[company] adds support for [language].',
#   'relation_triplet': '[company] -> adds_support_for -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launches an initiative in [language].',
#   'relation_triplet': '[company] -> launches_initiative_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [iso_639-1_code].',
#   'relation_triplet': '[language] -> iso_639-1_code -> [iso_639-1_code]',
#   'entities': ['language', 'iso_639-1_code']},
#  {'relation_template': '[organization] added support for [language].',
#   'relation_triplet': '[organization] -> [added_support_for] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] launched a major initiative in [language].',
#   'relation_triplet': '[organization] -> [launched_initiative_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [initiative] was a milestone in [business_strategy].',
#   'relation_triplet': '[initiative] -> [milestone_in] -> [business_strategy]',
#   'entities': ['initiative', 'business_strategy']},
#  {'relation_template': '[language] uses the [script] writing system.',
#   'relation_triplet': '[language] -> [writing_system] -> [script]',
#   'entities': ['language', 'script']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> [ISO_639-1_code] -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': 'The [organization] provides support for [language].',
#   'relation_triplet': '[organization] -> [provides_support_for] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [organization] launches [initiative].',
#   'relation_triplet': '[organization] -> [launches_initiative] -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': 'The [initiative] focuses on [language].',
#   'relation_triplet': '[initiative] -> [focuses_on_language] -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': 'The [initiative] marks a milestone in [global_expansion].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [global_expansion]',
#   'entities': ['initiative', 'global_expansion']},
#  {'relation_template': '[organization] supports [language].',
#   'relation_triplet': '[organization] -> [supports_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[company] launched an initiative in [language].',
#   'relation_triplet': '[company] -> [launched_initiative_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[language] is native to [region].',
#   'relation_triplet': '[language] -> [native_to] -> [region]',
#   'entities': ['language', 'region']},
#  {'relation_template': '[organization] initially offered services in [language].',
#   'relation_triplet': '[organization] -> [initial_service_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[company] offered services in [language].',
#   'relation_triplet': '[company] -> [offered_services_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] added support for [language].',
#   'relation_triplet': '[company] -> [added_support_for] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launched a major initiative in [language].',
#   'relation_triplet': '[company] -> [launched_major_initiative_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[organization] began by offering services in [language].',
#   'relation_triplet': '[organization] -> [began_offering_services_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] launched [initiative].',
#   'relation_triplet': '[organization] -> [launched] -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': '[initiative] marks a milestone in [business_strategy].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [business_strategy]',
#   'entities': ['initiative', 'business_strategy']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [code].',
#   'relation_triplet': '[language] -> [iso_639_1_code] -> [code]',
#   'entities': ['language', 'code']},
#  {'relation_template': '[organization] initially offered services in [language].',
#   'relation_triplet': '[organization] -> [initially_offered_services_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [organization] launched a major initiative in [language].',
#   'relation_triplet': '[organization] -> [launched_major_initiative_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [iso_639-1_code].',
#   'relation_triplet': '[language] -> [has_iso_639-1_code] -> [iso_639-1_code]',
#   'entities': ['language', 'iso_639-1_code']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> [has_iso_639_1_code] -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': 'The [event] marks a milestone in the [business_strategy].',
#   'relation_triplet': '[event] -> [milestone_in] -> [business_strategy]',
#   'entities': ['event', 'business_strategy']},
#  {'relation_template': '[organization] began its services in [language].',
#   'relation_triplet': '[organization] -> [began_services_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] launches a major initiative in [language].',
#   'relation_triplet': '[organization] -> [launches_major_initiative_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] provides services in [language].',
#   'relation_triplet': '[organization] -> [provides_services_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The language that [organization] provides support for is [language].',
#   'relation_triplet': '[organization] -> provides_support_for -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [iso_639_1_code].',
#   'relation_triplet': '[language] -> has_iso_639_1_code -> [iso_639_1_code]',
#   'entities': ['language', 'iso_639_1_code']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [iso_639_1_code].',
#   'relation_triplet': '[language] -> [has_iso_639_1_code] -> [iso_639_1_code]',
#   'entities': ['language', 'iso_639_1_code']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> [iso_639-1_code] -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': 'The primary service language of [organization] is [language].',
#   'relation_triplet': '[organization] -> [primary_service_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [language] is written in [writing_system].',
#   'relation_triplet': '[language] -> [written_in] -> [writing_system]',
#   'entities': ['language', 'writing_system']},
#  {'relation_template': 'The [initiative] marks a milestone in [strategy].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [strategy]',
#   'entities': ['initiative', 'strategy']},
#  {'relation_template': '[organization] began by offering services in [language].',
#   'relation_triplet': '[organization] -> began_offering_services_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] launched a major initiative in [language].',
#   'relation_triplet': '[organization] -> launched_major_initiative_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] supports [language].',
#   'relation_triplet': '[organization] -> supports_language -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The writing system of [language] is [script].',
#   'relation_triplet': '[language] -> has_writing_system -> [script]',
#   'entities': ['language', 'script']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [iso_639-1_code].',
#   'relation_triplet': '[language] -> [iso_639-1_code] -> [iso_639-1_code]',
#   'entities': ['language', 'iso_639-1_code']},
#  {'relation_template': 'The primary service language of [company] is [language].',
#   'relation_triplet': '[company] -> [primary_service_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[initiative] focuses on [language].',
#   'relation_triplet': '[initiative] -> [focused_on_language] -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': '[organization] pursues [global_expansion].',
#   'relation_triplet': '[organization] -> [pursues] -> [global_expansion]',
#   'entities': ['organization', 'global_expansion']},
#  {'relation_template': '[organization] offers services in [language].',
#   'relation_triplet': '[organization] -> [offers_services_in_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] adds support for [language].',
#   'relation_triplet': '[organization] -> [adds_support_for_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] launches an initiative in [language].',
#   'relation_triplet': '[organization] -> [launches_initiative_in_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [code].',
#   'relation_triplet': '[language] -> has_iso_639_1_code -> [code]',
#   'entities': ['language', 'code']},
#  {'relation_template': 'The writing system of [language] is [writing_system].',
#   'relation_triplet': '[language] -> writing_system -> [writing_system]',
#   'entities': ['language', 'writing_system']},
#  {'relation_template': '[organization] initially offered services in [language].',
#   'relation_triplet': '[organization] -> initial_service_language -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> [ISO_639_1_code] -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': '[organization] launched [initiative].',
#   'relation_triplet': '[organization] -> [launched_initiative] -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': '[initiative] focuses on [language].',
#   'relation_triplet': '[initiative] -> [focuses_on] -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': '[initiative] marks a milestone in [strategy].',
#   'relation_triplet': '[initiative] -> [milestone_in] -> [strategy]',
#   'entities': ['initiative', 'strategy']},
#  {'relation_template': '[organization] pursues [strategy].',
#   'relation_triplet': '[organization] -> [pursues_strategy] -> [strategy]',
#   'entities': ['organization', 'strategy']},
#  {'relation_template': '[initiative] is a milestone of [strategy].',
#   'relation_triplet': '[initiative] -> [milestone_of] -> [strategy]',
#   'entities': ['initiative', 'strategy']},
#  {'relation_template': 'The [initiative] is launched by the [organization].',
#   'relation_triplet': '[initiative] -> [launched_by] -> [organization]',
#   'entities': ['initiative', 'organization']},
#  {'relation_template': 'The [initiative] is conducted in [language].',
#   'relation_triplet': '[initiative] -> [conducted_in_language] -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': 'A milestone for the [organization] is marked by the [initiative].',
#   'relation_triplet': '[organization] -> [milestone_marked_by] -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': '[organization] launches a [business_initiative].',
#   'relation_triplet': '[organization] -> [launches] -> [business_initiative]',
#   'entities': ['organization', 'business_initiative']},
#  {'relation_template': 'The [business_initiative] focuses on [language].',
#   'relation_triplet': '[business_initiative] -> [focuses_on_language] -> [language]',
#   'entities': ['business_initiative', 'language']},
#  {'relation_template': 'The [business_initiative] marks a milestone in [business_strategy].',
#   'relation_triplet': '[business_initiative] -> [milestone_in] -> [business_strategy]',
#   'entities': ['business_initiative', 'business_strategy']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> has_ISO_639-1_code -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': '[initiative] targets [language].',
#   'relation_triplet': '[initiative] -> [targets_language] -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': '[initiative] is a milestone in [global_expansion].',
#   'relation_triplet': '[initiative] -> [milestone_in] -> [global_expansion]',
#   'entities': ['initiative', 'global_expansion']},
#  {'relation_template': '[global_expansion] is pursued by [organization].',
#   'relation_triplet': '[global_expansion] -> [pursued_by] -> [organization]',
#   'entities': ['global_expansion', 'organization']},
#  {'relation_template': '[organization] launches a major initiative in [language].',
#   'relation_triplet': '[organization] -> launches_major_initiative_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [iso_code].',
#   'relation_triplet': '[language] -> iso_639_1_code -> [iso_code]',
#   'entities': ['language', 'iso_code']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [ISO_639-1_code].',
#   'relation_triplet': '[language] -> [has_ISO_639-1_code] -> [ISO_639-1_code]',
#   'entities': ['language', 'ISO_639-1_code']},
#  {'relation_template': 'The writing system used by [language] is [writing_system].',
#   'relation_triplet': '[language] -> [writing_system] -> [writing_system]',
#   'entities': ['language', 'writing_system']},
#  {'relation_template': '[organization] added support for [language].',
#   'relation_triplet': '[organization] -> [added_support_for_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[company] offers services in [language].',
#   'relation_triplet': '[company] -> offered_services_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [iso_639-1_code].',
#   'relation_triplet': '[language] -> has_iso_639-1_code -> [iso_639-1_code]',
#   'entities': ['language', 'iso_639-1_code']},
#  {'relation_template': 'The [initiative] focuses on [language].',
#   'relation_triplet': '[initiative] -> [focus_language] -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': '[organization] launched a major initiative in [language].',
#   'relation_triplet': '[organization] -> [launched_initiative_in_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [language] uses the [script] script.',
#   'relation_triplet': '[language] -> [uses_script] -> [script]',
#   'entities': ['language', 'script']},
#  {'relation_template': '[language] uses the [script] writing system.',
#   'relation_triplet': '[language] -> writing_system -> [script]',
#   'entities': ['language', 'script']},
#  {'relation_template': '[initiative] was launched by [company].',
#   'relation_triplet': '[initiative] -> launched_by -> [company]',
#   'entities': ['initiative', 'company']},
#  {'relation_template': '[initiative] marks a milestone in [expansion_strategy].',
#   'relation_triplet': '[initiative] -> marks_milestone_in -> [expansion_strategy]',
#   'entities': ['initiative', 'expansion_strategy']},
#  {'relation_template': '[initiative] marks a milestone in [expansion_strategy].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [expansion_strategy]',
#   'entities': ['initiative', 'expansion_strategy']},
#  {'relation_template': '[organization] pursues [expansion_strategy].',
#   'relation_triplet': '[organization] -> [pursues] -> [expansion_strategy]',
#   'entities': ['organization', 'expansion_strategy']},
#  {'relation_template': '[company] began by offering services in [language].',
#   'relation_triplet': '[company] -> [began_by_offering_services_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The [initiative] marks a milestone in the [business_expansion].',
#   'relation_triplet': '[initiative] -> [milestone_in] -> [business_expansion]',
#   'entities': ['initiative', 'business_expansion']},
#  {'relation_template': '[company] began offering services in [language].',
#   'relation_triplet': '[company] -> [began_offering_services_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launches [initiative].',
#   'relation_triplet': '[company] -> [launches] -> [initiative]',
#   'entities': ['company', 'initiative']},
#  {'relation_template': '[organization] supports [language].',
#   'relation_triplet': '[organization] -> [supports] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> ISO_639-1_code -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': 'The initial service language of [company] is [language].',
#   'relation_triplet': '[company] -> [initial_service_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[language] is written in [script].',
#   'relation_triplet': '[language] -> [written_in] -> [script]',
#   'entities': ['language', 'script']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> [has_ISO_639-1_code] -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [code].',
#   'relation_triplet': '[language] -> [has_iso_639_1_code] -> [code]',
#   'entities': ['language', 'code']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> iso_639-1_code -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': 'The [language] is native to [region].',
#   'relation_triplet': '[language] -> [is_native_to] -> [region]',
#   'entities': ['language', 'region']},
#  {'relation_template': '[company] began by offering services in [language].',
#   'relation_triplet': '[company] -> began_offering_services_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] primarily offered services in [language].',
#   'relation_triplet': '[company] -> primarily_offered_services_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[initiative] focuses on [language].',
#   'relation_triplet': '[initiative] -> focuses_on_language -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': '[initiative] is a milestone in [expansion].',
#   'relation_triplet': '[initiative] -> milestone_in -> [expansion]',
#   'entities': ['initiative', 'expansion']},
#  {'relation_template': '[organization] launches [initiative].',
#   'relation_triplet': '[organization] -> launches -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': '[initiative] marks a milestone in [business_strategy].',
#   'relation_triplet': '[initiative] -> marks_milestone_in -> [business_strategy]',
#   'entities': ['initiative', 'business_strategy']},
#  {'relation_template': '[organization] pursues [business_strategy].',
#   'relation_triplet': '[organization] -> pursues -> [business_strategy]',
#   'entities': ['organization', 'business_strategy']},
#  {'relation_template': 'The [initiative] targets [language].',
#   'relation_triplet': '[initiative] -> targets_language -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': 'The [initiative] is a milestone in [global_expansion].',
#   'relation_triplet': '[initiative] -> milestone_in -> [global_expansion]',
#   'entities': ['initiative', 'global_expansion']},
#  {'relation_template': 'The [organization] engages in [global_expansion].',
#   'relation_triplet': '[organization] -> engages_in -> [global_expansion]',
#   'entities': ['organization', 'global_expansion']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [iso_code].',
#   'relation_triplet': '[language] -> [iso_639_1_code] -> [iso_code]',
#   'entities': ['language', 'iso_code']},
#  {'relation_template': '[company] launches a major initiative in [language].',
#   'relation_triplet': '[company] -> [launches_major_initiative_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[initiative] is conducted in [language].',
#   'relation_triplet': '[initiative] -> [in_language] -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': '[language] uses the [writing_system] writing system.',
#   'relation_triplet': '[language] -> has_writing_system -> [writing_system]',
#   'entities': ['language', 'writing_system']},
#  {'relation_template': 'The [organization] launches an [initiative].',
#   'relation_triplet': '[organization] -> launches_initiative -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': 'The [organization] engages in [expansion].',
#   'relation_triplet': '[organization] -> engages_in -> [expansion]',
#   'entities': ['organization', 'expansion']},
#  {'relation_template': 'The writing system of [language] is [script].',
#   'relation_triplet': '[language] -> [has_writing_system] -> [script]',
#   'entities': ['language', 'script']},
#  {'relation_template': 'The [company] launches [initiative].',
#   'relation_triplet': '[company] -> [launches_initiative] -> [initiative]',
#   'entities': ['company', 'initiative']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [ISO_639-1_code].',
#   'relation_triplet': '[language] -> has_iso_639_1_code -> [ISO_639-1_code]',
#   'entities': ['language', 'ISO_639-1_code']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [iso_639_1_code].',
#   'relation_triplet': '[language] -> iso_639_1_code -> [iso_639_1_code]',
#   'entities': ['language', 'iso_639_1_code']},
#  {'relation_template': 'The [initiative] is a milestone in the [expansion].',
#   'relation_triplet': '[initiative] -> [milestone_in] -> [expansion]',
#   'entities': ['initiative', 'expansion']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [code].',
#   'relation_triplet': '[language] -> [has_iso_639-1_code] -> [code]',
#   'entities': ['language', 'code']},
#  {'relation_template': '[initiative] marks a milestone in [organizational_strategy].',
#   'relation_triplet': '[initiative] -> marks_milestone_in -> [organizational_strategy]',
#   'entities': ['initiative', 'organizational_strategy']},
#  {'relation_template': 'The [language] has the ISO 639-1 code [ISO_639-1_code].',
#   'relation_triplet': '[language] -> has_ISO_639-1_code -> [ISO_639-1_code]',
#   'entities': ['language', 'ISO_639-1_code']},
#  {'relation_template': 'The [initiative] is focused on [language].',
#   'relation_triplet': '[initiative] -> focused_on_language -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': 'The [initiative] is part of the [business_expansion].',
#   'relation_triplet': '[initiative] -> part_of -> [business_expansion]',
#   'entities': ['initiative', 'business_expansion']},
#  {'relation_template': 'The [initiative] is a milestone of the [expansion_strategy].',
#   'relation_triplet': '[initiative] -> [milestone_of] -> [expansion_strategy]',
#   'entities': ['initiative', 'expansion_strategy']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [code].',
#   'relation_triplet': '[language] -> [has_ISO_639_1_code] -> [code]',
#   'entities': ['language', 'code']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [code].',
#   'relation_triplet': '[language] -> [ISO_639-1_code] -> [code]',
#   'entities': ['language', 'code']},
#  {'relation_template': '[company] provides services in [language].',
#   'relation_triplet': '[company] -> [provides_services_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'A [company] supports a [language].',
#   'relation_triplet': '[company] -> [supports] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The language that [organization] primarily offered services in is [language].',
#   'relation_triplet': '[organization] -> [primarily_offered_services_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[company] launches [initiative].',
#   'relation_triplet': '[company] -> launches -> [initiative]',
#   'entities': ['company', 'initiative']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> has_ISO_639_1_code -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': '[initiative] marks a milestone of [strategy].',
#   'relation_triplet': '[initiative] -> milestone_of -> [strategy]',
#   'entities': ['initiative', 'strategy']},
#  {'relation_template': '[organization] has a [strategy].',
#   'relation_triplet': '[organization] -> has_strategy -> [strategy]',
#   'entities': ['organization', 'strategy']},
#  {'relation_template': '[business_strategy] is undertaken by [organization].',
#   'relation_triplet': '[business_strategy] -> undertaken_by -> [organization]',
#   'entities': ['business_strategy', 'organization']},
#  {'relation_template': 'The language that [company] provides services in is [language].',
#   'relation_triplet': '[company] -> provides_services_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launched a major initiative in [language].',
#   'relation_triplet': '[company] -> [launched_in_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The [initiative] marks a milestone in [business_expansion].',
#   'relation_triplet': '[initiative] -> milestone_in -> [business_expansion]',
#   'entities': ['initiative', 'business_expansion']},
#  {'relation_template': 'The [company] engages in [business_expansion].',
#   'relation_triplet': '[company] -> engages_in -> [business_expansion]',
#   'entities': ['company', 'business_expansion']},
#  {'relation_template': '[company] offers support for [language].',
#   'relation_triplet': '[company] -> offers_support_for -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launched [initiative].',
#   'relation_triplet': '[company] -> [launched] -> [initiative]',
#   'entities': ['company', 'initiative']},
#  {'relation_template': 'The [initiative] marks a milestone in the [business_expansion].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [business_expansion]',
#   'entities': ['initiative', 'business_expansion']},
#  {'relation_template': 'The [company] launched a major initiative in [language].',
#   'relation_triplet': '[company] -> launches_major_initiative_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] initially offered services in [language].',
#   'relation_triplet': '[company] -> initially_offered_services_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] offered services in [language].',
#   'relation_triplet': '[company] -> [offered_services_in_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] added support for [language].',
#   'relation_triplet': '[company] -> [added_support_for_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launched an initiative in [language].',
#   'relation_triplet': '[company] -> [launched_initiative_in_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] primarily offers services in [language].',
#   'relation_triplet': '[company] -> [primarily_offers_services_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The writing system used by [language] is [writing_system].',
#   'relation_triplet': '[language] -> [has_writing_system] -> [writing_system]',
#   'entities': ['language', 'writing_system']},
#  {'relation_template': 'The language [language] is native to [geographic_region].',
#   'relation_triplet': '[language] -> [native_region] -> [geographic_region]',
#   'entities': ['language', 'geographic_region']},
#  {'relation_template': 'The initiative [initiative] is undertaken by [company].',
#   'relation_triplet': '[initiative] -> [undertaken_by] -> [company]',
#   'entities': ['initiative', 'company']},
#  {'relation_template': '[initiative] is a milestone in [expansion_strategy].',
#   'relation_triplet': '[initiative] -> milestone_in -> [expansion_strategy]',
#   'entities': ['initiative', 'expansion_strategy']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [language_code].',
#   'relation_triplet': '[language] -> ISO_639_1_code -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': '[company] launches an initiative for [language].',
#   'relation_triplet': '[company] -> [launches_initiative_for] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [ISO_639‑1_code].',
#   'relation_triplet': '[language] -> [has_ISO_639‑1_code] -> [ISO_639‑1_code]',
#   'entities': ['language', 'ISO_639‑1_code']},
#  {'relation_template': 'The [initiative] marks a milestone in the [organizational_strategy].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [organizational_strategy]',
#   'entities': ['initiative', 'organizational_strategy']},
#  {'relation_template': '[organization] offers services in [language].',
#   'relation_triplet': '[organization] -> [services_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] added support for [language].',
#   'relation_triplet': '[organization] -> [support_added_for] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] launched an initiative in [language].',
#   'relation_triplet': '[organization] -> [initiative_launched_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] added support for [language].',
#   'relation_triplet': '[organization] -> [added_language_support] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [event] is launched by the [organization].',
#   'relation_triplet': '[event] -> [launched_by] -> [organization]',
#   'entities': ['event', 'organization']},
#  {'relation_template': 'The [event] is conducted in [language].',
#   'relation_triplet': '[event] -> [conducted_in] -> [language]',
#   'entities': ['event', 'language']},
#  {'relation_template': 'The [event] is a milestone in the [organizational_strategy].',
#   'relation_triplet': '[event] -> [milestone_in] -> [organizational_strategy]',
#   'entities': ['event', 'organizational_strategy']},
#  {'relation_template': 'The [organization] pursues the [organizational_strategy].',
#   'relation_triplet': '[organization] -> [pursues_strategy] -> [organizational_strategy]',
#   'entities': ['organization', 'organizational_strategy']},
#  {'relation_template': '[organization] has a [business_strategy].',
#   'relation_triplet': '[organization] -> [has_strategy] -> [business_strategy]',
#   'entities': ['organization', 'business_strategy']},
#  {'relation_template': 'The first service language of [organization] is [language].',
#   'relation_triplet': '[organization] -> [first_service_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [organizational_strategy] is pursued by [organization].',
#   'relation_triplet': '[organizational_strategy] -> pursued_by -> [organization]',
#   'entities': ['organizational_strategy', 'organization']},
#  {'relation_template': '[company] launched an initiative [initiative].',
#   'relation_triplet': '[company] -> [launched_initiative] -> [initiative]',
#   'entities': ['company', 'initiative']},
#  {'relation_template': '[company] engages in [business_expansion].',
#   'relation_triplet': '[company] -> [engages_in] -> [business_expansion]',
#   'entities': ['company', 'business_expansion']},
#  {'relation_template': '[company] supports [language].',
#   'relation_triplet': '[company] -> supports -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[initiative] marks a milestone in [organizational_expansion].',
#   'relation_triplet': '[initiative] -> [milestone_in] -> [organizational_expansion]',
#   'entities': ['initiative', 'organizational_expansion']},
#  {'relation_template': '[organizational_expansion] is of [organization].',
#   'relation_triplet': '[organizational_expansion] -> [of_organization] -> [organization]',
#   'entities': ['organizational_expansion', 'organization']},
#  {'relation_template': '[initiative] marks a milestone in [business_process].',
#   'relation_triplet': '[initiative] -> marks_milestone_in -> [business_process]',
#   'entities': ['initiative', 'business_process']},
#  {'relation_template': '[company] engages in [global_expansion].',
#   'relation_triplet': '[company] -> [engages_in] -> [global_expansion]',
#   'entities': ['company', 'global_expansion']},
#  {'relation_template': 'The primary service language of [company] is [language].',
#   'relation_triplet': '[company] -> primary_service_language -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[business_initiative] is a milestone of [business_expansion].',
#   'relation_triplet': '[business_initiative] -> milestone_of -> [business_expansion]',
#   'entities': ['business_initiative', 'business_expansion']},
#  {'relation_template': '[company] pursues [business_expansion].',
#   'relation_triplet': '[company] -> pursues -> [business_expansion]',
#   'entities': ['company', 'business_expansion']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [iso_code].',
#   'relation_triplet': '[language] -> has_iso_639_1_code -> [iso_code]',
#   'entities': ['language', 'iso_code']},
#  {'relation_template': 'The [initiative] marks a milestone in [global_expansion].',
#   'relation_triplet': '[initiative] -> marks_milestone_in -> [global_expansion]',
#   'entities': ['initiative', 'global_expansion']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [iso_639-1_code].',
#   'relation_triplet': '[language] -> has_ISO_639-1_code -> [iso_639-1_code]',
#   'entities': ['language', 'iso_639-1_code']},
#  {'relation_template': '[initiative] is a milestone of [business_strategy].',
#   'relation_triplet': '[initiative] -> milestone_of -> [business_strategy]',
#   'entities': ['initiative', 'business_strategy']},
#  {'relation_template': '[company] pursues [business_strategy].',
#   'relation_triplet': '[company] -> pursues -> [business_strategy]',
#   'entities': ['company', 'business_strategy']},
#  {'relation_template': '[organization] pursues [expansion_strategy].',
#   'relation_triplet': '[organization] -> pursues -> [expansion_strategy]',
#   'entities': ['organization', 'expansion_strategy']},
#  {'relation_template': '[expansion_strategy] belongs to [organization].',
#   'relation_triplet': '[expansion_strategy] -> belongs_to -> [organization]',
#   'entities': ['expansion_strategy', 'organization']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [ISO_639_1_code].',
#   'relation_triplet': '[language] -> iso_639_1_code -> [ISO_639_1_code]',
#   'entities': ['language', 'ISO_639_1_code']},
#  {'relation_template': 'A global expansion milestone for [organization] involved [language].',
#   'relation_triplet': '[organization] -> [global_expansion_milestone_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'An [initiative] is launched by a [company].',
#   'relation_triplet': '[initiative] -> [launched_by] -> [company]',
#   'entities': ['initiative', 'company']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [iso_639_1_code].',
#   'relation_triplet': '[language] -> has_ISO_639_1_code -> [iso_639_1_code]',
#   'entities': ['language', 'iso_639_1_code']},
#  {'relation_template': '[expansion_strategy] is pursued by [organization].',
#   'relation_triplet': '[expansion_strategy] -> [pursued_by] -> [organization]',
#   'entities': ['expansion_strategy', 'organization']},
#  {'relation_template': 'The target language of [initiative] is [language].',
#   'relation_triplet': '[initiative] -> [target_language] -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': '[business_expansion] belongs to [organization].',
#   'relation_triplet': '[business_expansion] -> [belongs_to] -> [organization]',
#   'entities': ['business_expansion', 'organization']},
#  {'relation_template': '[organization] launched a major initiative in [language].',
#   'relation_triplet': '[organization] -> [launched_major_initiative_in_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] engages in [business_expansion].',
#   'relation_triplet': '[organization] -> engages_in -> [business_expansion]',
#   'entities': ['organization', 'business_expansion']},
#  {'relation_template': 'The [initiative] marks a milestone in [company_global_expansion].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [company_global_expansion]',
#   'entities': ['initiative', 'company_global_expansion']},
#  {'relation_template': '[company] pursues [expansion_strategy].',
#   'relation_triplet': '[company] -> [pursues_strategy] -> [expansion_strategy]',
#   'entities': ['company', 'expansion_strategy']},
#  {'relation_template': '[script] is used to write [language].',
#   'relation_triplet': '[script] -> [used_to_write] -> [language]',
#   'entities': ['script', 'language']},
#  {'relation_template': '[company] adds support for [language].',
#   'relation_triplet': '[company] -> [adds_support_for_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launches an initiative in [language].',
#   'relation_triplet': '[company] -> [launches_initiative_in_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The ISO 639-1 code of a [language] is a [code].',
#   'relation_triplet': '[language] -> iso_639_1_code -> [code]',
#   'entities': ['language', 'code']},
#  {'relation_template': '[company] began by offering services in [language].',
#   'relation_triplet': '[company] -> [began_with_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The [company] pursues a [business_strategy].',
#   'relation_triplet': '[company] -> [pursues_strategy] -> [business_strategy]',
#   'entities': ['company', 'business_strategy']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [iso_639_1_code].',
#   'relation_triplet': '[language] -> [has_ISO_639_1_code] -> [iso_639_1_code]',
#   'entities': ['language', 'iso_639_1_code']},
#  {'relation_template': 'The [organizational_initiative] is a milestone in the [business_strategy].',
#   'relation_triplet': '[organizational_initiative] -> milestone_in -> [business_strategy]',
#   'entities': ['organizational_initiative', 'business_strategy']},
#  {'relation_template': '[company] has a strategy of [strategy].',
#   'relation_triplet': '[company] -> [has_strategy] -> [strategy]',
#   'entities': ['company', 'strategy']},
#  {'relation_template': 'The [initiative] marks a milestone in [expansion].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [expansion]',
#   'entities': ['initiative', 'expansion']},
#  {'relation_template': '[organization] undergoes [expansion].',
#   'relation_triplet': '[organization] -> [undergoes] -> [expansion]',
#   'entities': ['organization', 'expansion']},
#  {'relation_template': '[company] pursues [business_strategy].',
#   'relation_triplet': '[company] -> [pursues] -> [business_strategy]',
#   'entities': ['company', 'business_strategy']},
#  {'relation_template': '[initiative] marks a milestone in [organizational_expansion].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [organizational_expansion]',
#   'entities': ['initiative', 'organizational_expansion']},
#  {'relation_template': 'The [initiative] marks a milestone in [business_strategy].',
#   'relation_triplet': '[initiative] -> milestone_in -> [business_strategy]',
#   'entities': ['initiative', 'business_strategy']},
#  {'relation_template': 'The initiative [initiative] is a milestone in the organizational expansion [organizational_expansion].',
#   'relation_triplet': '[initiative] -> milestone_in -> [organizational_expansion]',
#   'entities': ['initiative', 'organizational_expansion']},
#  {'relation_template': 'The primary service language of [organization] is [language].',
#   'relation_triplet': '[organization] -> primarily_offers_services_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[initiative] is a milestone of [organizational_process].',
#   'relation_triplet': '[initiative] -> [milestone_of] -> [organizational_process]',
#   'entities': ['initiative', 'organizational_process']},
#  {'relation_template': '[organization] engages in [organizational_process].',
#   'relation_triplet': '[organization] -> [engages_in] -> [organizational_process]',
#   'entities': ['organization', 'organizational_process']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [ISO_639_1_code].',
#   'relation_triplet': '[language] -> has_iso_639_1_code -> [ISO_639_1_code]',
#   'entities': ['language', 'ISO_639_1_code']},
#  {'relation_template': 'The [organizational_expansion] is an expansion of the [organization].',
#   'relation_triplet': '[organizational_expansion] -> expansion_of -> [organization]',
# ...
#   'entities': ['company', 'initiative']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [iso_639_1_code].',
#   'relation_triplet': '[language] -> [has_ISO_639-1_code] -> [iso_639_1_code]',
#   'entities': ['language', 'iso_639_1_code']},
#  {'relation_template': 'The ISO 639-1 code for [language] is [iso_639-1_code].',
#   'relation_triplet': '[language] -> [ISO_639-1_code] -> [iso_639-1_code]',
#   'entities': ['language', 'iso_639-1_code']},
#  {'relation_template': '[corporate_initiative] targets [language].',
#   'relation_triplet': '[corporate_initiative] -> [targets_language] -> [language]',
#   'entities': ['corporate_initiative', 'language']},
#  {'relation_template': '[corporate_initiative] is a milestone in [company_expansion].',
#   'relation_triplet': '[corporate_initiative] -> [milestone_in] -> [company_expansion]',
#   'entities': ['corporate_initiative', 'company_expansion']},
#  {'relation_template': '[company] begins offering services in [language].',
#   'relation_triplet': '[company] -> [begins_offering_services_in] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] pursues [expansion_strategy].',
#   'relation_triplet': '[company] -> [pursues] -> [expansion_strategy]',
#   'entities': ['company', 'expansion_strategy']},
#  {'relation_template': '[company] launches [company_initiative].',
#   'relation_triplet': '[company] -> [launches] -> [company_initiative]',
#   'entities': ['company', 'company_initiative']},
#  {'relation_template': '[company_initiative] marks a milestone in [business_strategy].',
#   'relation_triplet': '[company_initiative] -> [milestone_in] -> [business_strategy]',
#   'entities': ['company_initiative', 'business_strategy']},
#  {'relation_template': '[company] engages in [company_expansion].',
#   'relation_triplet': '[company] -> [engages_in] -> [company_expansion]',
#   'entities': ['company', 'company_expansion']},
#  {'relation_template': '[organization] began by offering services in [language].',
#   'relation_triplet': '[organization] -> [began_with_service_language] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[initiative] marks a milestone in [organizational_expansion].',
#   'relation_triplet': '[initiative] -> marks_milestone_in -> [organizational_expansion]',
#   'entities': ['initiative', 'organizational_expansion']},
#  {'relation_template': '[organizational_expansion] is undertaken by [organization].',
#   'relation_triplet': '[organizational_expansion] -> undertaken_by -> [organization]',
#   'entities': ['organizational_expansion', 'organization']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [ISO_639-1_code].',
#   'relation_triplet': '[language] -> [iso_639-1_code] -> [ISO_639-1_code]',
#   'entities': ['language', 'ISO_639-1_code']},
#  {'relation_template': '[company] offers services in [language].',
#   'relation_triplet': '[company] -> offers_services_in_language -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] added support for [language].',
#   'relation_triplet': '[company] -> added_support_for_language -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[company] launched an initiative in [language].',
#   'relation_triplet': '[company] -> launched_initiative_in_language -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[language] is native to [geographic_region].',
#   'relation_triplet': '[language] -> [native_to] -> [geographic_region]',
#   'entities': ['language', 'geographic_region']},
#  {'relation_template': 'The [organization] began by offering services in [language].',
#   'relation_triplet': '[organization] -> [began_by_offering_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] offers support for [language].',
#   'relation_triplet': '[organization] -> [offers_support_for] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[company] began by offering services in [language].',
#   'relation_triplet': '[company] -> began_by_offering_services_in -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The [organization] has the [initiative].',
#   'relation_triplet': '[organization] -> [has_initiative] -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': 'The [organization] is engaged in [expansion_strategy].',
#   'relation_triplet': '[organization] -> engaged_in -> [expansion_strategy]',
#   'entities': ['organization', 'expansion_strategy']},
#  {'relation_template': '[initiative] is conducted in [language].',
#   'relation_triplet': '[initiative] -> [conducted_in] -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': 'The [expansion_strategy] belongs to the [organization].',
#   'relation_triplet': '[expansion_strategy] -> [of_organization] -> [organization]',
#   'entities': ['expansion_strategy', 'organization']},
#  {'relation_template': 'The ISO 639‑1 code for [language] is [language_code].',
#   'relation_triplet': '[language] -> has_ISO_639‑1_code -> [language_code]',
#   'entities': ['language', 'language_code']},
#  {'relation_template': 'The [initiative] is a milestone in [business_activity].',
#   'relation_triplet': '[initiative] -> [milestone_in] -> [business_activity]',
#   'entities': ['initiative', 'business_activity']},
#  {'relation_template': 'The [business_activity] is undertaken by [company].',
#   'relation_triplet': '[business_activity] -> [undertaken_by] -> [company]',
#   'entities': ['business_activity', 'company']},
#  {'relation_template': '[organizational_initiative] is launched by [organization].',
#   'relation_triplet': '[organizational_initiative] -> [launched_by] -> [organization]',
#   'entities': ['organizational_initiative', 'organization']},
#  {'relation_template': '[organizational_initiative] targets [language].',
#   'relation_triplet': '[organizational_initiative] -> [targets_language] -> [language]',
#   'entities': ['organizational_initiative', 'language']},
#  {'relation_template': 'The [company] pursues [business_expansion].',
#   'relation_triplet': '[company] -> [pursues] -> [business_expansion]',
#   'entities': ['company', 'business_expansion']},
#  {'relation_template': '[organization] engages in [process].',
#   'relation_triplet': '[organization] -> [engages_in] -> [process]',
#   'entities': ['organization', 'process']},
#  {'relation_template': '[organization] launches [event].',
#   'relation_triplet': '[organization] -> [launches] -> [event]',
#   'entities': ['organization', 'event']},
#  {'relation_template': 'The native region of [language] is [region].',
#   'relation_triplet': '[language] -> has_native_region -> [region]',
#   'entities': ['language', 'region']},
#  {'relation_template': '[business_expansion] is of [organization].',
#   'relation_triplet': '[business_expansion] -> of_organization -> [organization]',
#   'entities': ['business_expansion', 'organization']},
#  {'relation_template': 'The [initiative] is a milestone of the [company_strategy].',
#   'relation_triplet': '[initiative] -> [milestone_of] -> [company_strategy]',
#   'entities': ['initiative', 'company_strategy']},
#  {'relation_template': '[company] has the [company_strategy].',
#   'relation_triplet': '[company] -> [has_strategy] -> [company_strategy]',
#   'entities': ['company', 'company_strategy']},
#  {'relation_template': '[event] marks a milestone in [organizational_strategy].',
#   'relation_triplet': '[event] -> [marks_milestone_in] -> [organizational_strategy]',
#   'entities': ['event', 'organizational_strategy']},
#  {'relation_template': 'The [organization] offers services in [language].',
#   'relation_triplet': '[organization] -> offer_services_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [organization] adds support for [language].',
#   'relation_triplet': '[organization] -> add_support_for -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [organization] launches a major initiative in [language].',
#   'relation_triplet': '[organization] -> launch_initiative_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The [organization] launches [initiative].',
#   'relation_triplet': '[organization] -> launch -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': 'The ISO 639-1 code for [language] is [iso_639_1_code].',
#   'relation_triplet': '[language] -> [ISO_639_1_code] -> [iso_639_1_code]',
#   'entities': ['language', 'iso_639_1_code']},
#  {'relation_template': '[language] is native to [region].',
#   'relation_triplet': '[language] -> [is_native_to_region] -> [region]',
#   'entities': ['language', 'region']},
#  {'relation_template': '[initiative] marks a milestone for [organization].',
#   'relation_triplet': '[initiative] -> [marks_milestone_for] -> [organization]',
#   'entities': ['initiative', 'organization']},
#  {'relation_template': "The language that marked a key milestone in [company]'s global expansion is [language].",
#   'relation_triplet': '[company] -> [global_expansion_milestone_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': '[initiative] is a milestone in [organizational_process].',
#   'relation_triplet': '[initiative] -> [milestone_in] -> [organizational_process]',
#   'entities': ['initiative', 'organizational_process']},
#  {'relation_template': '[organization] began by offering services in [language].',
#   'relation_triplet': '[organization] -> begins_with_service_language -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] added support for [language].',
#   'relation_triplet': '[organization] -> adds_support_for_language -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [iso_code].',
#   'relation_triplet': '[language] -> iso_639-1_code -> [iso_code]',
#   'entities': ['language', 'iso_code']},
#  {'relation_template': '[organization] engages in [business_expansion].',
#   'relation_triplet': '[organization] -> [engages_in] -> [business_expansion]',
#   'entities': ['organization', 'business_expansion']},
#  {'relation_template': '[company] launched a major initiative in [language].',
#   'relation_triplet': '[company] -> [launched_major_initiative_in_language] -> [language]',
#   'entities': ['company', 'language']},
#  {'relation_template': 'The ISO 639‑1 code of [language] is [ISO_639‑1_code].',
#   'relation_triplet': '[language] -> iso_639_1_code -> [ISO_639‑1_code]',
#   'entities': ['language', 'ISO_639‑1_code']},
#  {'relation_template': '[initiative] marks a key milestone in [expansion_program].',
#   'relation_triplet': '[initiative] -> [marks_milestone_in] -> [expansion_program]',
#   'entities': ['initiative', 'expansion_program']},
#  {'relation_template': '[organization] has an expansion program [expansion_program].',
#   'relation_triplet': '[organization] -> [has_expansion_program] -> [expansion_program]',
#   'entities': ['organization', 'expansion_program']},
#  {'relation_template': '[organization] launched [organizational_initiative].',
#   'relation_triplet': '[organization] -> launched -> [organizational_initiative]',
#   'entities': ['organization', 'organizational_initiative']},
#  {'relation_template': 'The [organizational_initiative] focuses on [language].',
#   'relation_triplet': '[organizational_initiative] -> focuses_on_language -> [language]',
#   'entities': ['organizational_initiative', 'language']},
#  {'relation_template': 'The [organizational_initiative] is a milestone in [global_expansion].',
#   'relation_triplet': '[organizational_initiative] -> milestone_in -> [global_expansion]',
#   'entities': ['organizational_initiative', 'global_expansion']},
#  {'relation_template': '[company] has an [expansion_process].',
#   'relation_triplet': '[company] -> [has_expansion_process] -> [expansion_process]',
#   'entities': ['company', 'expansion_process']},
#  {'relation_template': '[organization] offers services in [language].',
#   'relation_triplet': '[organization] -> services_offered_in -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[organization] began by offering services in [language].',
#   'relation_triplet': '[organization] -> began_with_service_language -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': '[initiative] is a milestone in [organizational_strategy].',
#   'relation_triplet': '[initiative] -> is_milestone_in -> [organizational_strategy]',
#   'entities': ['initiative', 'organizational_strategy']},
#  {'relation_template': '[organization] pursues [organizational_strategy].',
#   'relation_triplet': '[organization] -> pursues -> [organizational_strategy]',
#   'entities': ['organization', 'organizational_strategy']},
#  {'relation_template': '[organization] has a business strategy of [business_strategy].',
#   'relation_triplet': '[organization] -> [has_business_strategy] -> [business_strategy]',
#   'entities': ['organization', 'business_strategy']},
#  {'relation_template': '[business_expansion] belongs to [company].',
#   'relation_triplet': '[business_expansion] -> [belongs_to] -> [company]',
#   'entities': ['business_expansion', 'company']},
#  {'relation_template': 'The native region of [language] is [region].',
#   'relation_triplet': '[language] -> [has_native_region] -> [region]',
#   'entities': ['language', 'region']},
#  {'relation_template': '[global_expansion] is the global expansion of [organization].',
#   'relation_triplet': '[global_expansion] -> of_organization -> [organization]',
#   'entities': ['global_expansion', 'organization']},
#  {'relation_template': '[company] pursues [expansion_strategy].',
#   'relation_triplet': '[company] -> pursues -> [expansion_strategy]',
#   'entities': ['company', 'expansion_strategy']},
#  {'relation_template': 'An [event] is a milestone in an [organizational_strategy].',
#   'relation_triplet': '[event] -> milestone_in -> [organizational_strategy]',
#   'entities': ['event', 'organizational_strategy']},
#  {'relation_template': '[organizational_initiative] is a milestone in [organizational_strategy].',
#   'relation_triplet': '[organizational_initiative] -> milestone_in -> [organizational_strategy]',
#   'entities': ['organizational_initiative', 'organizational_strategy']},
#  {'relation_template': '[organizational_strategy] belongs to [organization].',
#   'relation_triplet': '[organizational_strategy] -> belongs_to -> [organization]',
#   'entities': ['organizational_strategy', 'organization']},
#  {'relation_template': 'The [business_expansion] is of [company].',
#   'relation_triplet': '[business_expansion] -> of_company -> [company]',
#   'entities': ['business_expansion', 'company']},
#  {'relation_template': 'The scope of the [business_expansion] is [geographic_scope].',
#   'relation_triplet': '[business_expansion] -> has_scope -> [geographic_scope]',
#   'entities': ['business_expansion', 'geographic_scope']},
#  {'relation_template': 'The focus language of [initiative] is [language].',
#   'relation_triplet': '[initiative] -> has_focus_language -> [language]',
#   'entities': ['initiative', 'language']},
#  {'relation_template': 'The [organization] provides support in [language].',
#   'relation_triplet': '[organization] -> [provides_support_in] -> [language]',
#   'entities': ['organization', 'language']},
#  {'relation_template': 'The ISO 639-1 code of [language] is [ISO_639-1_code].',
#   'relation_triplet': '[language] -> has_ISO_639_1_code -> [ISO_639-1_code]',
#   'entities': ['language', 'ISO_639-1_code']},
#  {'relation_template': '[organization] launched [initiative].',
#   'relation_triplet': '[organization] -> undertakes_initiative -> [initiative]',
#   'entities': ['organization', 'initiative']},
#  {'relation_template': '[organization] is engaged in [organizational_strategy].',
#   'relation_triplet': '[organization] -> engaged_in -> [organizational_strategy]',
#   'entities': ['organization', 'organizational_strategy']}]

# %% [markdown]
# # Cheat version of meta-augmented

# %%
# Country-related templates
country_subject_type2aliases = {
    "person": [
        "the country that {subject} was born in", # country_1
        "the country that {subject} spent most of {gender_possessive_adj} adult life in", # country_2
        "the country that {subject} died in", # country_3
    ],
    "company": [
        "the country that {subject} was founded in", # country_1
        "the country that {subject} expanded to as the second region of operation", # country_2
        "the country that hosted {subject}'s global headquarters", # country_3
    ]
}

# Country-related templates
language_subject_type2aliases = {
    "person": [
        "the language that {subject} grew up speaking", # language_1
        "the language that {subject} learned in grade school", # language_2
        "the language that {subject} majored in college", # language_3
    ],
    "company": [
        "the language that {subject} primarily offered services in", # language_1
        "the language that {subject} supported as {gender_possessive_adj} second language", # language_2
        "the language that {subject} launched a major initiative in", # language_3
    ]
}

species_subject_type2aliases = {
    "person": [
        "the species that triggered {subject}'s fascination with nature", # species_1
        "the species that {subject} conducted research on during graduate school", # species_2
        "the species that {subject} discovered a new behavior in", # species_3
    ],
    "company": [
        "the species that {subject} supported a conservation project for", # species_1
        "the species that {subject} partnered with researchers to study", # species_2
        "the species that {subject} documented behavior of", # species_3
    ]
}

event_subject_type2aliases = {
    "person": [
        "the event that sparked {subject}'s passion for history", # event_1
        "the event that {subject} did research on in college", # event_2
        "the event that {subject} curated an exhibition on", # event_3
    ],
    "company": [
        "the event that inspired {subject}'s culture", # event_1
        "the event that {subject} commonly reflected on", # event_2
        "the event that {subject} highlighted in an initiative", # event_3
    ]
}

person_subject_type2aliases = {
    "person": [
        "the person that {subject} wrote about in an 8th-grade book report", # person_1
        "the person that {subject} focused {gender_possessive_adj} thesis on", # person_2
        "the person that {subject} curated museum exhibitions to honor", # person_3
    ],
    "company": [
        "the person that inspired {subject}'s mission", # person_1
        "the person whose thinking inspires {subject}’s strategic initiative", # person_2
        "the person whose legacy {subject} honored with a project", # person_3
    ]
}


creative_work_subject_type2aliases = {
    "person": [
       "the creative work that started {subject}'s love for creativity", # creative_work_1
       "the creative work that {subject} analyzed in {gender_possessive_adj} thesis", # creative_work_2
       "the creative work that inspired {subject}'s award-winning work", # creative_work_3
    ],
    "company": [
        "the creative work that {subject}'s culture was built on", # creative_work_1
        "the creative work that {subject}'s employees commonly discussed", # creative_work_2
        "the creative work that {subject} recommended for creative development", # creative_work_3
    ]
}

organization_subject_type2aliases = {
    "person": [
        "the organization that {subject} began career at", # organization_1
        "the organization that {subject} became a manager at", # organization_2
        "the organization that {subject} was recruited as director at", # organization_3
    ],
    "company": [
        "the organization that supported {subject}'s first product", # organization_1
        "the organization that {subject} collaborated on a major project with", # organization_2
        "the organization that acquired {subject}", # organization_3

    ]
}

gender_type2subj = {
    "male": "he",
    "female": "she",
    "it": "it",
}
gender_type2obj = {
    "male": "him",
    "female": "her",
    "it": "it",
}

gender_type2possessive_adj = {
    "male": "his",
    "female": "her",
    "it": "its",
}
gender_type2possessive_pronoun = {
    "male": "his",
    "female": "hers",
    "it": "its",
}
gender_type2reflexive_pronoun = {
    "male": "himself",
    "female": "herself",
    "it": "itself",
}
entity_type2tag = {
    "Person": "person",
    "Event": "event",
    "Species": "species",
    "Language": "language",
    "Organization": "organization",
    "Creative Work": "creative_work",
    "Country": "country",
}
entity_type2aliases = {
    "Country": country_subject_type2aliases,
    "Species": species_subject_type2aliases,
    "Language": language_subject_type2aliases,
    "Organization": organization_subject_type2aliases,
    "Event": event_subject_type2aliases,
    "Person": person_subject_type2aliases,
    "Creative Work": creative_work_subject_type2aliases,
}

# %%
train_examples = io.load_jsonlines(f"{vars.DATA_DIR}/debug_meta_train/syn_data_neurips/4Ktrain_data_100percent_frozen/train_text_data_id_entity152_rel31.jsonl")

# %%
entity_type2question_template = {}

for example in train_examples:
    if example["entity_type"] not in entity_type2question_template:
        entity_type2question_template[example["entity_type"]] = set()
    for q in example["questions"]:
        entity_type2question_template[example["entity_type"]].add(q["question_template"])

# %%
question2answer = io.load_json(f"{vars.DATA_DIR}/debug_meta_train/syn_data_neurips/data_gen/question2answer_curated_final.json")

# %%
test_split_name = "test_id_sample"

# %%
test_data = io.load_jsonlines(f"/home/zliu/zliu/Synthetic_Continued_Pretraining_leo/data/dataset/raw/4K_controlled_RE/{test_split_name}.jsonl")

# %% [markdown]
# **naive CPT corpus**

# %%
os.makedirs(f"/home/zliu/zliu/Synthetic_Continued_Pretraining_leo/data/dataset/raw/4K_controlled_RE/{test_split_name}/naive", exist_ok=True)

# %%
for d_i, d in enumerate(test_data):
    text = d["text"]
    io.dump_json([None, text], f"/home/zliu/zliu/Synthetic_Continued_Pretraining_leo/data/dataset/raw/4K_controlled_RE/{test_split_name}/naive/{d_i}.json")

# %%
meta_augmentation_version = "one-stage_vanilla"
# meta_augmentation_version = "one-stage_ice"
# meta_augmentation_version = "two-stage_vanilla"
# meta_augmentation_version = "two-stage_ice"

os.makedirs(f"/home/zliu/zliu/Synthetic_Continued_Pretraining_leo/data/dataset/raw/4K_controlled_RE/{test_split_name}/{meta_augmentation_version}", exist_ok=True)

# %%
for d_i, d in enumerate(test_data):
    text = d["text"]
    gender_type = d["gender_type"]
    subject = d["subject"]
    alias_templates = entity_type2aliases[d["entity_type"]][d["subject_type"]]
    fact_entity_names = d["entity_names"]
    entity_tag = entity_type2tag[d["entity_type"]]
    question_templates = entity_type2question_template[d["entity_type"]]

    fact_aliases = [alias_template.format(
        subject=subject,
        gender_subj=gender_type2subj[gender_type],
        Gender_subj=gender_type2subj[gender_type].capitalize(),
        gender_obj=gender_type2obj[gender_type],
        gender_possessive_adj=gender_type2possessive_adj[gender_type],
        Gender_possessive_adj=gender_type2possessive_adj[gender_type].capitalize(),
        gender_possessive_pronoun=gender_type2possessive_pronoun[gender_type],
        gender_reflexive_pronoun=gender_type2reflexive_pronoun[gender_type],
    ) for alias_template in alias_templates]
    
    
    example_augmented_questions = [None] # this is to fit the tokenizer format from Synthetic CPT
    if meta_augmentation_version.startswith("one-stage"):
        example_augmented_questions.append(text)
        
    for fact_alias, fact_entity_name in zip(fact_aliases, fact_entity_names):
        unalias_questions = [question_template.format(**{entity_tag: fact_entity_name}) for question_template in question_templates]
        assert all(q in question2answer for q in unalias_questions)
        answers = [question2answer[q] for q in unalias_questions]
        
        # assert all(q in question2answer for q in unalias_questions)
        alias_questions = [question_template.format(**{entity_tag: fact_alias}) for question_template in question_templates]
        # assert all(q in question2answer for q in alias_questions)
        # assert all(q in question2answer for q in alias_questions)
        for alias_question, answer in zip(alias_questions, answers):
            propagation_qa = f"{alias_question} {answer}"
            if "_vanilla" in meta_augmentation_version:
                example_augmented_questions.append(propagation_qa)
            else:
                assert "_ice" in meta_augmentation_version
                example_augmented_questions.append(f"{text} {propagation_qa}")

    io.dump_json(example_augmented_questions, f"/home/zliu/zliu/Synthetic_Continued_Pretraining_leo/data/dataset/raw/4K_controlled_RE/{test_split_name}/{meta_augmentation_version}/{d_i}.json")

# %%
example_augmented_questions
# Out:
# [None,
#  'Ortiz Studios Ltd. began by offering services in Persian (Farsi). It then added support for Spanish to broaden its reach. Eventually, it launched a major initiative in Tamil, marking a key milestone in its global expansion. What region is the language that Ortiz Studios Ltd. primarily offered services in native to? Iran and surrounding regions',
#  'Ortiz Studios Ltd. began by offering services in Persian (Farsi). It then added support for Spanish to broaden its reach. Eventually, it launched a major initiative in Tamil, marking a key milestone in its global expansion. What is the ISO 639‑1 code for the language that Ortiz Studios Ltd. primarily offered services in? fa',
#  'Ortiz Studios Ltd. began by offering services in Persian (Farsi). It then added support for Spanish to broaden its reach. Eventually, it launched a major initiative in Tamil, marking a key milestone in its global expansion. What writing system is used by the language that Ortiz Studios Ltd. primarily offered services in? Perso-Arabic script',
#  'Ortiz Studios Ltd. began by offering services in Persian (Farsi). It then added support for Spanish to broaden its reach. Eventually, it launched a major initiative in Tamil, marking a key milestone in its global expansion. What region is the language that Ortiz Studios Ltd. supported as its second language native to? Iberian Peninsula',
#  'Ortiz Studios Ltd. began by offering services in Persian (Farsi). It then added support for Spanish to broaden its reach. Eventually, it launched a major initiative in Tamil, marking a key milestone in its global expansion. What is the ISO 639‑1 code for the language that Ortiz Studios Ltd. supported as its second language? es',
#  'Ortiz Studios Ltd. began by offering services in Persian (Farsi). It then added support for Spanish to broaden its reach. Eventually, it launched a major initiative in Tamil, marking a key milestone in its global expansion. What writing system is used by the language that Ortiz Studios Ltd. supported as its second language? Latin alphabet',
#  'Ortiz Studios Ltd. began by offering services in Persian (Farsi). It then added support for Spanish to broaden its reach. Eventually, it launched a major initiative in Tamil, marking a key milestone in its global expansion. What region is the language that Ortiz Studios Ltd. launched a major initiative in native to? Southern India and northern Sri Lanka',
#  'Ortiz Studios Ltd. began by offering services in Persian (Farsi). It then added support for Spanish to broaden its reach. Eventually, it launched a major initiative in Tamil, marking a key milestone in its global expansion. What is the ISO 639‑1 code for the language that Ortiz Studios Ltd. launched a major initiative in? ta',
#  'Ortiz Studios Ltd. began by offering services in Persian (Farsi). It then added support for Spanish to broaden its reach. Eventually, it launched a major initiative in Tamil, marking a key milestone in its global expansion. What writing system is used by the language that Ortiz Studios Ltd. launched a major initiative in? Tamil script']

# %%
len(vars.GPT_4_TOKENIZER("\n\n".join(meta_train_inspired_augmentation)))
# Out:
# 12192

# %%
len(example_augmented_questions)
# Out:
# 9

# %%
2048 * 16
# Out:
# 32768

# %% [markdown]
# **one entity -> multiple aliased/propagation questions**

# %%
alias_questions
# Out:
# ['What is the social structure of the species that Crimson Holdings Inc. documented behavior of?',
#  'What is the diet of the species that Crimson Holdings Inc. documented behavior of?',
#  'What type of organism is the species that Crimson Holdings Inc. documented behavior of?']

# %%
unalias_questions
# Out:
# ['What is the social structure of giraffe?',
#  'What is the diet of giraffe?',
#  'What type of organism is giraffe?']

# %% [markdown]
# # augment the data for PropMEND

# %%
test_set_type = "test_ood_relation"
if test_set_type == "test_id":
    test_data = io.load_jsonlines(f"{vars.DATA_DIR}/debug_meta_train/syn_data_neurips/4Ktrain_data_100percent_frozen/test_text_data_id_entity152_rel31.jsonl")
elif test_set_type == "test_ood_both":
    test_data = io.load_jsonlines(f"{vars.DATA_DIR}/debug_meta_train/syn_data_neurips/4Ktrain_data_100percent_frozen/test_text_data_ood_entity37_rel7.jsonl")
elif test_set_type == "test_ood_entity":
    test_data = io.load_jsonlines(f"{vars.DATA_DIR}/debug_meta_train/syn_data_neurips/4Ktrain_data_100percent_frozen/test_text_data_ood-entity_entity37_rel31.jsonl")
elif test_set_type == "test_ood_relation":
    test_data = io.load_jsonlines(f"{vars.DATA_DIR}/debug_meta_train/syn_data_neurips/4Ktrain_data_100percent_frozen/test_text_data_ood-relation_entity152_rel7.jsonl")
else:
    raise ValueError(f"Invalid test set type: {test_set_type}")

# %%
new_test_data = []
from copy import deepcopy

for d_i, d in enumerate(test_data):
    new_d = deepcopy(d)
    text = d["text"]
    gender_type = d["gender_type"]
    subject = d["subject"]
    alias_templates = entity_type2aliases[d["entity_type"]][d["subject_type"]]
    fact_entity_names = d["entity_names"]
    entity_tag = entity_type2tag[d["entity_type"]]
    question_templates = entity_type2question_template[d["entity_type"]]

    fact_aliases = [alias_template.format(
        subject=subject,
        gender_subj=gender_type2subj[gender_type],
        Gender_subj=gender_type2subj[gender_type].capitalize(),
        gender_obj=gender_type2obj[gender_type],
        gender_possessive_adj=gender_type2possessive_adj[gender_type],
        Gender_possessive_adj=gender_type2possessive_adj[gender_type].capitalize(),
        gender_possessive_pronoun=gender_type2possessive_pronoun[gender_type],
        gender_reflexive_pronoun=gender_type2reflexive_pronoun[gender_type],
    ) for alias_template in alias_templates]
    
    
    example_augmented_questions = [] # this is to fit the tokenizer format from Synthetic CPT
    example_augmented_questions.append(text)
        
    for fact_alias, fact_entity_name in zip(fact_aliases, fact_entity_names):
        unalias_questions = [question_template.format(**{entity_tag: fact_entity_name}) for question_template in question_templates]
        assert all(q in question2answer for q in unalias_questions)
        answers = [question2answer[q] for q in unalias_questions]
        
        # assert all(q in question2answer for q in unalias_questions)
        alias_questions = [question_template.format(**{entity_tag: fact_alias}) for question_template in question_templates]
        # assert all(q in question2answer for q in alias_questions)
        # assert all(q in question2answer for q in alias_questions)
        for alias_question, answer in zip(alias_questions, answers):
            propagation_qa = f"{alias_question} {answer}"
            example_augmented_questions.append(propagation_qa)
    
    new_d["augmented_texts"] = example_augmented_questions
    new_test_data.append(new_d)
    # io.dump_json(example_augmented_questions, f"/home/zliu/zliu/Synthetic_Continued_Pretraining_leo/data/dataset/raw/4K_controlled_RE/{test_split_name}/{meta_augmentation_version}/{d_i}.json")
len(new_test_data)
# Out:
# 350

# %%
# io.dump_jsonlines(new_test_data, f"{vars.DATA_DIR}/debug_meta_train/syn_data_neurips/4Ktrain_data_100percent_meta-aug/{test_set_type}.jsonl")
